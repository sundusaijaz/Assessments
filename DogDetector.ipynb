# %%
import dlib, os, cv2
import numpy as np
import matplotlib.pyplot as plt
import imutils

# %%
#load model
detector = dlib.cnn_face_detection_model_v1('dogHeadDetector.dat')

# %%
img_path = 'dog.jpg'
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#Detect Faces
dets = detector(img, upsample_num_times=1)
print(dets)
img_result = img.copy()
for i, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {} Confidence: {}".
          format(i, d.rect.left(), d.rect.top(), d.rect.right(), d.rect.bottom(), d.confidence))

    x1, y1 = d.rect.left(), d.rect.top()
    x2, y2 = d.rect.right(), d.rect.bottom()

    cv2.rectangle(img_result, pt1=(x1, y1), pt2=(x2, y2), thickness=2, color=(255,0,0), lineType=cv2.LINE_AA)
plt.imshow(img_result)
# Out:
# <dlib.mmod_rectangles object at 0x000001DC880C6768>
# Detection 0: Left: 280 Top: 102 Right: 449 Bottom: 272 Confidence: 1.0480859279632568

# %%
crop_img = img_result[y1:y2, x1:x2]
plt.imshow(crop_img)
